# %% [markdown]
# <a href="https://colab.research.google.com/github/abinayasri-s/first-git/blob/main/chatbot_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def chatbot(user_input):
    user_input = user_input.lower()
    if "hello" in user_input:
        return "Hi there! I'm a simple AI."
    elif "how are you" in user_input:
        return "I'm just code, but I'm doing great!"
    elif "bye" in user_input:
        return "Goodbye! Have a nice day."
    else:
        return "I don't understand that yet."

# Demo
print("Chatbot Demo. Type something!")
while True:
    text = input("You: ")
    if text.lower() == "exit":
        break
    print("AI:", chatbot(text))
# Out:
# Chatbot Demo. Type something!
# You: hello
# AI: Hi there! I'm a simple AI.
# You: how are you
# AI: I'm just code, but I'm doing great!
# You: bye
# AI: Goodbye! Have a nice day.
# You: ena panra
# AI: I don't understand that yet.
# You: exit
